# %%
import pandas as pd

df = pd.read_csv("../data/raw/HR_Analytics.csv")
df.head()

# %%
# Kiểm tra missing values
df.isnull().sum()

# %%
# Kiểu dữ liệu
df.dtypes

# %%
# Thống kê mô tả & outlier
df.describe().T

# %%
# Số lượng giá trị duy nhất của mỗi cột
df.nunique()
